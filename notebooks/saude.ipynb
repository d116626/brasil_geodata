# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
rras = gpd.read_file('../maps/saude/rras/rras.shp')
rs = gpd.read_file('../maps/saude/regioes de saude/regioes_de_saude.shp')
drs = gpd.read_file('../maps/saude/drs/drs.shp')

# %%
rs['geometry'].plot()

# %%
drs.head()
# Out:
#      ID        DEPARTAMEN                                           geometry
# 0  3501  GRANDE SÃO PAULO  POLYGON ((-45.96146 -23.49656, -45.95128 -23.4...
# 1  3502         ARAÇATUBA  POLYGON ((-49.84273 -21.35486, -49.84793 -21.3...
# 2  3503        ARARAQUARA  POLYGON ((-48.04441 -22.07275, -48.04751 -22.0...
# 3  3504  BAIXADA SANTISTA  MULTIPOLYGON (((-46.90199 -24.38809, -46.90199...
# 4  3505          BARRETOS  POLYGON ((-48.58071 -21.16521, -48.58351 -21.1...

# %%
drs['geometry'].plot()

# %%
rras.head()
# Out:
#       RRAS                                           geometry
# 0  RRAS 01  POLYGON ((-46.40999 -23.81485, -46.42674 -23.8...
# 1  RRAS 02  POLYGON ((-45.96146 -23.49656, -45.95128 -23.4...
# 2  RRAS 03  POLYGON ((-46.63563 -23.25727, -46.63563 -23.2...
# 3  RRAS 04  POLYGON ((-47.03785 -23.83479, -47.03785 -23.8...
# 4  RRAS 05  POLYGON ((-46.79930 -23.47116, -46.79210 -23.4...

# %%
rras['geometry'].plot()
